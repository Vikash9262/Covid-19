# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("V:\PYTHON\Data Analytic Project\Covid-19\country_wise_latest.csv")
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.head(20)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %%
df.tail(20)
# Out:
#            Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 167              Thailand       3297      58       3111      128          6
# 168           Timor-Leste         24       0          0       24          0
# 169                  Togo        874      18        607      249          6
# 170   Trinidad and Tobago        148       8        128       12          1
# 171               Tunisia       1455      50       1157      248          3
# 172                Turkey     227019    5630     210469    10920        919
# 173                    US    4290259  148011    1325804  2816444      56336
# 174                Uganda       1128       2        986      140         13
# 175               Ukraine      67096    1636      37202    28258        835
# 176  United Arab Emirates      59177     345      52510     6322        264
# 177        United Kingdom     301708   45844       1437   254427        688
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %%
df["Country/Region"]
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
#               ...
# 182    West Bank and Gaza
# 183        Western Sahara
# 184                 Yemen
# 185                Zambia
# 186              Zimbabwe
# Name: Country/Region, Length: 187, dtype: object

# %%
df = df.drop("Active", axis=1)

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198        106          10
# 1        Albania       4880     144       2745        117           6
# 2        Algeria      27973    1163      18837        616           8
# 3        Andorra        907      52        803         10           0
# 4         Angola        950      41        242         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df['WHO Region'].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
sns.lineplot(x='New deaths',y='New recovered' , data = df)
plt.title("New Deaths vs New Recovered" , fontsize = 20)
plt.show()

# %%
sns.lineplot(x='New deaths',y='New recovered' , data = df , hue='WHO Region')
plt.title("New Deaths vs New Recovered" , fontsize = 20)
plt.show()

# %%
sns.lineplot(x='New deaths',y='New recovered' , data = df , hue='WHO Region', style='WHO Region')
plt.title("New Deaths vs New Recovered" , fontsize = 20)
plt.show()

# %%
sns.lineplot(x='New deaths',y='New recovered' , data = df , hue='WHO Region', style='WHO Region',markers=True)
# Out:
# <Axes: xlabel='New deaths', ylabel='New recovered'>

# %%
Sales = df.groupby("WHO Region")["New recovered"].sum().sort_index()
plt.figure(figsize = (9,5))
bars = plt.plot(Sales.index , Sales.values , marker='o',linestyle="--",color='red',linewidth=2)

plt.xlabel("WHO Region",fontsize=15)
plt.ylabel("New recovered",fontsize=15)
plt.title("WHO Region by New recovered",fontsize=23)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize = (15,6))
sns.barplot(x=df.Deaths  , y=df.Recovered)
plt.title("Deaths and Recovered Bar Graph",fontsize = 30)
plt.xlabel("Deaths",fontsize = 30)
plt.ylabel("Recovered",fontsize = 30)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
Bar = df['WHO Region'].value_counts()
Bar.plot(kind='bar',color=['red','green','yellow','blue','pink','black'])
plt.title("WHO Region bar Graph",fontsize = 23)
plt.xlabel("WHO Region",fontsize = 15)
plt.ylabel("Counts",fontsize = 15)
plt.tight_layout()
plt.xticks(rotation=-40)
plt.show()

# %%
Bar = df['WHO Region'].value_counts()
Bar.plot(kind='pie',autopct = '%1.1f%%' , color=['red','green','yellow','blue','pink','black'])
plt.title("WHO Region bar Graph",fontsize = 23)
plt.tight_layout()

plt.show()

# %% [markdown]
# # WHO Pie Chart Based on New RECOVERED

# %%
plt.figure(figsize=(5,5))
Cases= df.groupby("WHO Region")['New recovered'].sum()
plt.pie(Cases,labels=Cases.index , autopct='%1.1f%%')
plt.title("WHO Pie Chart ")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # WHO Pie Chart Based on New Cases

# %%
plt.figure(figsize=(5,5))
Cases= df.groupby("WHO Region")['New cases'].sum()
plt.pie(Cases,labels=Cases.index , autopct='%1.1f%%')
plt.title("WHO Pie Chart ")
plt.show()

# %% [markdown]
# # WHO Pie Chart Based on New Deaths

# %%
plt.figure(figsize=(5,5))
Cases= df.groupby("WHO Region")['New deaths'].sum()
plt.pie(Cases,labels=Cases.index , autopct='%1.1f%%')
plt.title("WHO Pie Chart ")
plt.show()

# %%
plt.figure(figsize=(5,5))
Cases= df.groupby("WHO Region")['New deaths'].sum()
myexplode = [0,0,0.2,0,0,0]
plt.pie(Cases,labels=Cases.index , autopct='%1.1f%%',explode=myexplode)
plt.title("WHO Pie Chart ")
plt.show()

# %%
Grouped = df.groupby(["New deaths","WHO Region"])["New recovered"].sum().unstack()

ax= Grouped.plot(kind='bar',figsize = (6,6) , title = "Outlet Tier by Item Fat Content")
plt.xlabel("Outlet Location Type")
plt.ylabel("Item Fat Content ")
plt.legend(title = "Item Fat Content")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Voilen Plot

# %%
sns.violinplot(x='New deaths',data=df)
# Out:
# <Axes: xlabel='New deaths'>

# %%
sns.violinplot(y='WHO Region',data=df)
# Out:
# <Axes: ylabel='WHO Region'>

# %%
sns.violinplot(x='New deaths',y='WHO Region' ,data=df)
# Out:
# <Axes: xlabel='New deaths', ylabel='WHO Region'>

# %%
sns.pairplot(df)
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15,8))
sns.boxplot(x='New deaths', y='New recovered' , data=df)
plt.show()

# %%
sns.displot(df["WHO Region"],kde=True)
plt.xticks(rotation=-45)
plt.show()

# %%
var=df['WHO Region'].value_counts().head(20)
var.plot(kind='barh',color='pink')
plt.title("WHO BARH graph",fontsize=23)
plt.xlabel("Count",fontsize = 15)
plt.ylabel("Who Region",fontsize = 15)
plt.show()

# %%
from wordcloud import WordCloud
text=' '.join(title for title in df['WHO Region'])
wordcloud= WordCloud(background_color='black').generate(text)
plt.imshow(wordcloud , interpolation = 'bilinear')
plt.axis('off')
plt.title("WordCloud of Covid-19")
plt.show()

# %%
sns.countplot(x='WHO Region' , data=df)
plt.xticks(rotation=-90)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (6,4))
sns.histplot(x="WHO Region",data=df,bins=50,hue="WHO Region")
plt.xticks(rotation=-90)
plt.title("Histplot of Who Region",fontsize=23)
plt.show()

# %%
plt.figure(figsize = (6,4))
sns.displot(x="WHO Region",data=df,bins=50,hue="WHO Region",rug=True,kde=True)
plt.xticks(rotation=-90)
plt.title("Displot of Who Region",fontsize=23)
plt.show()

# %%
plt.figure(figsize = (6,4))
sns.displot(x="WHO Region",data=df,bins=50,color='green',rug=True,kde=True)
plt.xticks(rotation=-90)
plt.title("Displot of Who Region",fontsize=23)
plt.show()

# %%
plt.scatter(df['WHO Region'],df['New deaths'],color='red',label='2024 Sales Data')
plt.xlabel('Who Region')
plt.ylabel('New deaths')
plt.legend()
plt.title('WHO Region vs New Deaths')
plt.grid(color='blue',linestyle=':',linewidth=1)
plt.xlim(1,5)
plt.ylim(0,7000)
plt.show()

# %%
plt.subplot(1,2,1)

var=df.groupby("WHO Region")['New deaths'].sum()
plt.pie(var , labels=var.index , autopct='%1.1f%%')
plt.title('NEW deaths vs WHO region')

plt.subplot(1,2,2)
plt.bar(df['WHO Region'],df['New deaths'], color='blue')
plt.title('NEW deaths vs WHO region')
plt.xticks(rotation=-90)
plt.tight_layout()

# %%
fg = sns.FacetGrid(df,hue="WHO Region")
fg.map(plt.scatter,"WHO Region","New deaths").add_legend()
plt.xticks(rotation=-90)
plt.show()
